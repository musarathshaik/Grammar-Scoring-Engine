# %% [markdown]
# # Grammar Scoring Engine for Voice Samples
#
# ### 📌 Project Goal
# The goal is to build a model that evaluates the grammatical quality of spoken English by analyzing voice samples. The output is a continuous score between 0 and 5.
#
# ---

# %% [markdown]
# # 📦 Install Required Libraries

# %%
# !pip install -q openai-whisper
# !pip install -q language-tool-python
# !pip install -q tqdm
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 800.5/800.5 kB 11.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 253.1/253.1 MB 6.5 MB/s eta 0:00:00
#   Building wheel for openai-whisper (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 kB 1.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.3/54.3 kB 2.4 MB/s eta 0:00:00

# %% [markdown]
# # 📚 Import Libraries

# %%
import os
import pandas as pd
import whisper
import language_tool_python
from tqdm import tqdm
from sklearn.metrics import mean_squared_error

# %% [markdown]
# # 📁 Define Paths

# %%
TRAIN_CSV_PATH = "/kaggle/input/shl-intern-hiring-assessment/dataset/train.csv"
TEST_CSV_PATH = "/kaggle/input/shl-intern-hiring-assessment/dataset/test.csv"
TRAIN_AUDIO_FOLDER = "/kaggle/input/shl-intern-hiring-assessment/dataset/audios_train"
TEST_AUDIO_FOLDER = "/kaggle/input/shl-intern-hiring-assessment/dataset/audios_test"

# %% [markdown]
# # 🧠 Load Models

# %%
print("🔄 Loading Whisper ASR model...")
asr_model = whisper.load_model("tiny")


print("🔍 Loading LanguageTool...")
grammar_tool = language_tool_python.LanguageTool('en-US')
# Out:
# 🔄 Loading Whisper ASR model...
# 100%|█████████████████████████████████████| 72.1M/72.1M [00:03<00:00, 20.8MiB/s]
# /usr/local/lib/python3.10/dist-packages/whisper/__init__.py:150: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(fp, map_location=device)
# 🔍 Loading LanguageTool...
# Downloading LanguageTool 6.5: 100%|██████████| 248M/248M [00:03<00:00, 65.6MB/s]

# %% [markdown]
# # 🧪 Grammar Scoring Function (0 to 5 scale)

# %%
def get_grammar_score(file_path):
    try:
        result = asr_model.transcribe(file_path)
        text = result['text']
    except Exception as e:
        print(f"❌ Error: {e}")
        text = ""
    
    errors = len(grammar_tool.check(text))
    score = max(0, 5 - (errors // 3))
    return text, score

# %% [markdown]
# # 📊 TRAINING: Process audios_train + train.csv

# %%
train_df = pd.read_csv(TRAIN_CSV_PATH)

train_texts = []
train_preds = []

print("🔁 Scoring training samples...\n")
for fname in tqdm(train_df['filename']):
    file_path = os.path.join(TRAIN_AUDIO_FOLDER, fname)
    text, score = get_grammar_score(file_path)
    train_texts.append(text)
    train_preds.append(score)

train_df['transcription'] = train_texts
train_df['predicted_score'] = train_preds

# 📉 Optional Evaluation
mse = mean_squared_error(train_df['label'], train_df['predicted_score'])
print(f"\n📉 Mean Squared Error (MSE) on train data: {mse:.4f}")
# Out:
# 🔁 Scoring training samples...
#   0%|          | 0/444 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   0%|          | 1/444 [00:13<1:38:32, 13.35s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   0%|          | 2/444 [00:16<52:54,  7.18s/it]  /usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   1%|          | 3/444 [00:18<37:50,  5.15s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   1%|          | 4/444 [00:22<34:20,  4.68s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   1%|          | 5/444 [00:27<34:52,  4.77s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   1%|▏         | 6/444 [00:32<35:13,  4.83s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#   2%|▏         | 7/444 [00:36<32:18,  4.44s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#
/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  91%|█████████ | 404/444 [56:39<09:09, 13.75s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  91%|█████████ | 405/444 [58:07<23:31, 36.19s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  91%|█████████▏| 406/444 [58:11<16:44, 26.44s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  92%|█████████▏| 407/444 [58:15<12:10, 19.74s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  92%|█████████▏| 408/444 [58:19<09:02, 15.07s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  92%|█████████▏| 409/444 [58:23<06:47, 11.65s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  92%|█████████▏| 410/444 [58:28<05:24,  9.55s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 411/444 [58:33<04:32,  8.26s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 412/444 [58:44<04:48,  9.02s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 413/444 [58:51<04:26,  8.61s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 414/444 [58:56<03:41,  7.38s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 415/444 [58:59<02:59,  6.20s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  94%|█████████▎| 416/444 [59:04<02:44,  5.88s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  94%|█████████▍| 417/444 [59:09<02:25,  5.40s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  94%|█████████▍| 418/444 [59:13<02:09,  4.97s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  94%|█████████▍| 419/444 [59:56<06:52, 16.52s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▍| 420/444 [1:00:01<05:14, 13.09s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▍| 421/444 [1:00:04<03:48,  9.94s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▌| 422/444 [1:00:35<05:59, 16.34s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▌| 423/444 [1:00:38<04:15, 12.18s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▌| 424/444 [1:01:18<06:52, 20.61s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  96%|█████████▌| 425/444 [1:01:51<07:45, 24.49s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  96%|█████████▌| 426/444 [1:01:56<05:31, 18.44s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  96%|█████████▌| 427/444 [1:02:00<03:59, 14.09s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  96%|█████████▋| 428/444 [1:02:05<03:01, 11.32s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  97%|█████████▋| 429/444 [1:02:09<02:16,  9.12s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  97%|█████████▋| 430/444 [1:02:54<04:41, 20.13s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  97%|█████████▋| 431/444 [1:02:57<03:13, 14.89s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  97%|█████████▋| 432/444 [1:03:30<04:04, 20.35s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 433/444 [1:04:05<04:31, 24.65s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 434/444 [1:04:44<04:49, 28.99s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 435/444 [1:05:11<04:16, 28.45s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 436/444 [1:05:19<02:58, 22.33s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 437/444 [1:05:24<01:58, 17.00s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  99%|█████████▊| 438/444 [1:05:29<01:20, 13.41s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  99%|█████████▉| 439/444 [1:05:36<00:57, 11.51s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  99%|█████████▉| 440/444 [1:05:40<00:37,  9.25s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  99%|█████████▉| 441/444 [1:05:43<00:22,  7.34s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|█████████▉| 442/444 [1:05:46<00:12,  6.18s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|█████████▉| 443/444 [1:06:02<00:08,  8.98s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|██████████| 444/444 [1:06:06<00:00,  8.93s/it]
# 📉 Mean Squared Error (MSE) on train data: 4.1284

# %% [markdown]
# # 🚀 TESTING: Predict grammar scores for audios_test

# %%
test_df = pd.read_csv(TEST_CSV_PATH)

test_texts = []
test_scores = []

print("🧪 Scoring test samples...\n")
for fname in tqdm(test_df['filename']):
    file_path = os.path.join(TEST_AUDIO_FOLDER, fname)
    text, score = get_grammar_score(file_path)
    test_texts.append(text)
    test_scores.append(score)

test_df['transcription'] = test_texts
test_df['predicted_score'] = test_scores
# Out:
# 🧪 Scoring test samples...
#   0%|          | 0/195 [00:00<?, ?it/s]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#
/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  82%|████████▏ | 160/195 [19:07<03:54,  6.71s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  83%|████████▎ | 161/195 [19:12<03:23,  5.97s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  83%|████████▎ | 162/195 [19:16<02:59,  5.44s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  84%|████████▎ | 163/195 [19:20<02:38,  4.96s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  84%|████████▍ | 164/195 [19:23<02:17,  4.45s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  85%|████████▍ | 165/195 [19:26<02:01,  4.05s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  85%|████████▌ | 166/195 [19:33<02:25,  5.02s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  86%|████████▌ | 167/195 [19:38<02:19,  4.97s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  86%|████████▌ | 168/195 [19:42<02:02,  4.55s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  87%|████████▋ | 169/195 [20:13<05:23, 12.43s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  87%|████████▋ | 170/195 [20:55<08:56, 21.46s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  88%|████████▊ | 171/195 [21:00<06:32, 16.37s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  88%|████████▊ | 172/195 [21:03<04:45, 12.42s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  89%|████████▊ | 173/195 [21:06<03:34,  9.73s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  89%|████████▉ | 174/195 [21:12<02:57,  8.46s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  90%|████████▉ | 175/195 [21:30<03:49, 11.47s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  90%|█████████ | 176/195 [22:24<07:37, 24.10s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  91%|█████████ | 177/195 [22:28<05:28, 18.22s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  91%|█████████▏| 178/195 [22:32<03:56, 13.93s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  92%|█████████▏| 179/195 [23:14<05:57, 22.34s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  92%|█████████▏| 180/195 [23:18<04:13, 16.93s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 181/195 [23:23<03:03, 13.12s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  93%|█████████▎| 182/195 [23:26<02:13, 10.25s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  94%|█████████▍| 183/195 [23:30<01:39,  8.27s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  94%|█████████▍| 184/195 [23:34<01:16,  6.99s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▍| 185/195 [23:38<00:59,  5.99s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  95%|█████████▌| 186/195 [23:41<00:47,  5.33s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  96%|█████████▌| 187/195 [23:46<00:41,  5.16s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  96%|█████████▋| 188/195 [24:43<02:24, 20.58s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  97%|█████████▋| 189/195 [24:47<01:34, 15.68s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  97%|█████████▋| 190/195 [25:43<02:18, 27.70s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 191/195 [25:51<01:28, 22.05s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  98%|█████████▊| 192/195 [26:27<01:18, 26.20s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  99%|█████████▉| 193/195 [26:31<00:38, 19.39s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
#  99%|█████████▉| 194/195 [26:35<00:14, 14.72s/it]/usr/local/lib/python3.10/dist-packages/whisper/transcribe.py:126: UserWarning: FP16 is not supported on CPU; using FP32 instead
#   warnings.warn("FP16 is not supported on CPU; using FP32 instead")
# 100%|██████████| 195/195 [27:30<00:00,  8.47s/it]

# %% [markdown]
# # 📤 Create submission.csv

# %%
submission_df = test_df[['filename', 'predicted_score']].rename(columns={'predicted_score': 'label'})
submission_df.to_csv("submission.csv", index=False)
print("✅ Submission file saved as submission.csv")
# Out:
# ✅ Submission file saved as submission.csv

# %%
import pandas as pd

submission_df = pd.read_csv("submission.csv")
submission_df.head()
# Out:
#          filename  label
# 0   audio_706.wav      0
# 1   audio_800.wav      4
# 2    audio_68.wav      4
# 3  audio_1267.wav      5
# 4   audio_683.wav      5

# %%
import pandas as pd

try:
    submission_df = pd.read_csv("submission.csv")
    print("📄 submission.csv preview:")
    print(submission_df.head())
except Exception as e:
    print("⚠️ Error reading submission.csv:", e)
# Out:
# 📄 submission.csv preview:
#          filename  label
# 0   audio_706.wav      0
# 1   audio_800.wav      4
# 2    audio_68.wav      4
# 3  audio_1267.wav      5
# 4   audio_683.wav      5
